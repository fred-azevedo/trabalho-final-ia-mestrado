# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

RANDOM_SEED = 123 
TEST_SIZE = 0.2

# %%
fraud_data = pd.read_csv("data/creditcard.csv")

# %%
fraud_data.head(n=5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
pd.value_counts(fraud_data['Class'], sort = True)
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
train, test = train_test_split(fraud_data, test_size=TEST_SIZE, random_state=RANDOM_SEED)

# %%
train.head(n=5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 99168    66999.0 -0.866221 -0.919624  2.020857 -1.525794 -1.035785  2.157966
# 69460    53439.0  0.967267 -0.179598  0.315800  1.354288 -0.273647  0.139429
# 71073    54140.0 -0.415673  1.080659  0.675844  0.789318  0.158613  0.430765
# 275238  166438.0  2.036473 -0.021870 -1.085398  0.500278 -0.106741 -1.226224
# 208891  137318.0 -4.420316 -3.367604  3.339102  6.050951  2.641524  0.359443
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 99168  -0.281997  0.608243 -0.595195  ...  0.511087  1.154578 -0.070794
# 69460  -0.005874  0.174708  0.195502  ... -0.015079 -0.078930 -0.131669
# 71073   0.135873  0.671417 -1.000854  ...  0.287891  0.782205  0.004812
# 275238  0.187898 -0.399751  0.320678  ...  0.159477  0.583649  0.091193
# 208891 -4.793559 -1.765357 -0.387127  ... -1.341109  1.123252 -0.526044
#
# ...

# %%
pd.value_counts(train['Class'], sort = True)
# Out:
# 0    227468
# 1       377
# Name: Class, dtype: int64

# %%
pd.value_counts(test['Class'], sort = True)
# Out:
# 0    56847
# 1      115
# Name: Class, dtype: int64
